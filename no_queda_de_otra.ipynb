# %% [markdown]
# <a href="https://colab.research.google.com/github/lmcanavals/acomplex/blob/main/no_queda_de_otra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://davidmegginson.github.io/ourairports-data/airports.csv")
data.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.947733    -151.692524         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
a = np.random.randint(1, len(data), size=(10))
a
# Out:
# array([12769, 20662,  1146, 23008, 10070, 11576, 15807,  4089,  3956,
#        17445])

# %%
path = data.iloc[a]

# %%
plt.subplots(figsize=(20, 15))
plt.scatter(data['longitude_deg'], data['latitude_deg'], s=1)
plt.plot(path['longitude_deg'], path['latitude_deg'], 'r-')

# %%
len(data)
# Out:
# 36419
